# %% [markdown]
# # Data Quality — Semua Sumber
#
# Jalankan **Run All** dengan kernel `env`. Keenam pemeriksaan di bawah memakai aturan yang sama untuk semua sumber. Hasil transaksi mengikuti 12 kolom tanpa customer_id; `product_id` memakai SKU asli dari Product Master.
#
# Product Master tetap berisi identitas produk dan harga referensi. Data sumber tetap utuh. Semua aturan dijalankan saat persiapan agar pemeriksaan duplikat sudah memperhitungkan hasil mapping produk; enam bagian berikut memperlihatkan hasil tiap pemeriksaan.

# %%
from pathlib import Path
import sys
from IPython.display import display

ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents]
            if (p / "pipeline/validation/analysis.py").exists())
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from pipeline.validation.analysis import (
    load_analysis, standard_data, missing_values, quality_issues,
    type_report, summary, export_analysis,
)

SOURCE = "all"
hasil = load_analysis(SOURCE, ROOT / "data/source")
data_bersih = standard_data(hasil)

# %% [markdown]
# ## 1. Missing value
#
# Field wajib: order ID, tanggal, produk, quantity, harga satuan, status; total transaksi Website juga wajib. Semua field master wajib. Baris yang tidak memenuhi syarat ditolak. Customer/kota/email yang tidak tersedia tetap kosong, tanpa dummy. Field opsional kosong yang tersedia dalam source dicatat sebagai warning.

# %%
display(missing_values(hasil))
display(quality_issues(hasil, "missing"))
# Out:
#        sumber               kolom  jumlah_kosong
# 0     product                 sku              0
# 1     product        product_name              0
# 2     product               brand              0
# 3     product            category              0
# 4     product               price              0
# 5      shopee            order_id              0
# 6      shopee          order_date              0
# 7      shopee        product_name              0
# 8      shopee                 qty              0
# 9      shopee          unit_price              0
# 10     shopee         customer_id              1
# 11     shopee       customer_name              1
# 12     shopee       customer_city              0
# 13     shopee      payment_method              1
# 14     shopee              status              0
# 15  tokopedia      transaction_id              0
# 16  tokopedia    transaction_date              0
# 17  tokopedia           item_name              0
# 18  tokopedia            quantity              0
# 19  tokopedia               price              0
# 20  tokopedia          buyer_name              4
# 21  tokopedia                city              6
# 22  tokopedia             payment              6
# 23  tokopedia              status              0
# 24    website          invoice_no              0
# 25    website          created_at              0
# 26    website  product_identifier              0
# 27    website            quantity              0
# 28    website          unit_price              0
# 29    website        total_amount              0
# 30    website      customer_email              1
# 31    website              status              0
# 32    offline      pos_receipt_no              0
# 33    offline             sold_at              0
# 34    offline    item_description              0
# 35    offline               units              0
# 36    offline          item_price              0
# 37    offline          store_name              0
# 38    offline          store_city              0
# 39    offline        payment_type              1
# 40    offline              status              0
#        sumber baris  tingkat           kolom           masalah nilai_asli
# 0      shopee    30  WARNING     customer_id  MISSING_OPTIONAL
# 1      shopee   335  WARNING  payment_method  MISSING_OPTIONAL
# 2      shopee   488  WARNING   customer_name  MISSING_OPTIONAL
# 3   tokopedia    28  WARNING            city  MISSING_OPTIONAL
# 4   tokopedia    30  WARNING      buyer_name  MISSING_OPTIONAL
# 5   tokopedia    35  WARNING         payment  MISSING_OPTIONAL
# 6   tokopedia    53  WARNING      buyer_name  MISSING_OPTIONAL
# 7   tokopedia   179  WARNING            city  MISSING_OPTIONAL
# 8   tokopedia   180  WARNING         payment  MISSING_OPTIONAL
# 9   tokopedia   199  WARNING         payment  MISSING_OPTIONAL
# 10  tokopedia   203  WARNING            city  MISSING_OPTIONAL
# 11  tokopedia   209  WARNING            city  MISSING_OPTIONAL
# 12  tokopedia   210  WARNING      buyer_name  MISSING_OPTIONAL
# 13  tokopedia   213  WARNING            city  MISSING_OPTIONAL
# 14  tokopedia   225  WARNING         payment  MISSING_OPTIONAL
# 15  tokopedia   227  WARNING            city  MISSING_OPTIONAL
# 16  tokopedia   242  WARNING         payment  MISSING_OPTIONAL
# 17  tokopedia   280  WARNING      buyer_name  MISSING_OPTIONAL
# 18  tokopedia   328  WARNING         payment  MISSING_OPTIONAL
# 19    website   379  WARNING  customer_email  MISSING_OPTIONAL
# 20    offline   311  WARNING    payment_type  MISSING_OPTIONAL

# %% [markdown]
# ## 2. Duplicate
#
# Business key: `(channel, order_id)` untuk dataset satu item per order saat ini; master memakai `product_id`/SKU. Record yang sama disimpan satu kali. Jika key sama tetapi nilainya berbeda, semua versi ditolak untuk ditinjau. Bila kelak order memiliki beberapa item, tambahkan line ID dari sumber.

# %%
display(quality_issues(hasil, "duplicate"))
# Out:
#        sumber baris tingkat         kolom                 masalah  nilai_asli
# 0      shopee   159    INFO  business_key  DUPLICATE_BUSINESS_KEY  SHP-000483
# 1      shopee   215    INFO  business_key  DUPLICATE_BUSINESS_KEY  SHP-000392
# 2      shopee   272    INFO  business_key  DUPLICATE_BUSINESS_KEY  SHP-000419
# 3      shopee   273    INFO  business_key  DUPLICATE_BUSINESS_KEY  SHP-000463
# 4      shopee   282    INFO  business_key  DUPLICATE_BUSINESS_KEY  SHP-000056
# 5      shopee   312    INFO  business_key  DUPLICATE_BUSINESS_KEY  SHP-000533
# 6      shopee   319    INFO  business_key  DUPLICATE_BUSINESS_KEY  SHP-000573
# 7      shopee   321    INFO  business_key  DUPLICATE_BUSINESS_KEY  SHP-000156
# 8      shopee   353    INFO  business_key  DUPLICATE_BUSINESS_KEY  SHP-000083
# 9      shopee   385    INFO  business_key  DUPLICATE_BUSINESS_KEY  SHP-000462
# 10     shopee   396    INFO  business_key  DUPLICATE_BUSINESS_KEY  SHP-000152
# 11     shopee   423    INFO  business_key  DUPLICATE_BUSINESS_KEY  SHP-000149
# 12     shopee   471    INFO  business_key  DUPLICATE_BUSINESS_KEY  SHP-000168
# 13     shopee   538    INFO  business_key  DUPLICATE_BUSINESS_KEY  SHP-000430
# 14     shopee   544    INFO  business_key  DUPLICATE_BUSINESS_KEY  SHP-000150
# 15     shopee   564    INFO  business_key  DUPLICATE_BUSINESS_KEY  SHP-000031
# 16     shopee   565    INFO  business_key  DUPLICATE_BUSINESS_KEY  SHP-000076
# 17     shopee   613    INFO  business_key  DUPLICATE_BUSINESS_KEY  SHP-000079
# 18  tokopedia   136    INFO  business_key  DUPLICATE_BUSINESS_KEY    TKP-0106
# 19    website   186    INFO  business_key  DUPLICATE_BUSINESS_KEY  WEB-002135
# 20    website   199    INFO  business_key  DUPLICATE_BUSINESS_KEY  WEB-002043
# 21    website   231    INFO  business_key  DUPLICATE_BUSINESS_KEY  WEB-002134
# 22    website   245    INFO  business_key  DUPLICATE_BUSINESS_KEY  WEB-002222
# 23    website   246    INFO  business_key  DUPLICATE_BUSINESS_KEY  WEB-002374
# 24    website   255    INFO  business_key  DUPLICATE_BUSINESS_KEY  WEB-002296
# 25    website   262    INFO  business_key  DUPLICATE_BUSINESS_KEY  WEB-002379
# 26    website   265    INFO  business_key  DUPLICATE_BUSINESS_KEY  WEB-002109
# 27    website   299    INFO  business_key  DUPLICATE_BUSINESS_KEY  WEB-002172
# 28    website   344    INFO  business_key  DUPLICATE_BUSINESS_KEY  WEB-002143
# 29    website   389    INFO  business_key  DUPLICATE_BUSINESS_KEY  WEB-002250
# 30    website   396    INFO  business_key  DUPLICATE_BUSINESS_KEY  WEB-002382
# 31    offline    20    INFO  business_key  DUPLICATE_BUSINESS_KEY  POS-003220
# 32    offline    93    INFO  business_key  DUPLICATE_BUSINESS_KEY  POS-003317
# 33    offline   173    INFO  business_key  DUPLICATE_BUSINESS_KEY  POS-003089
# 34    offline   177    INFO  business_key  DUPLICATE_BUSINESS_KEY  POS-003329
# 35    offline   240    INFO  business_key  DUPLICATE_BUSINESS_KEY  POS-003086
# 36    offline   254    INFO  business_key  DUPLICATE_BUSINESS_KEY  POS-003299
# 37    offline   275    INFO  business_key  DUPLICATE_BUSINESS_KEY  POS-003326
# 38    offline   286    INFO  business_key  DUPLICATE_BUSINESS_KEY  POS-003063
# 39    offline   318    INFO  business_key  DUPLICATE_BUSINESS_KEY  POS-003079
# 40    offline   355    INFO  business_key  DUPLICATE_BUSINESS_KEY  POS-003149

# %% [markdown]
# ## 3. Invalid value
#
# Quantity wajib integer positif. Harga wajib positif dan maksimal dua desimal. Total harus sama dengan quantity × harga satuan. Status dataset saat ini: `Completed`, `Cancelled`, `Returned`; status lain ditolak. Harga berbeda dari master diberi warning karena mungkin promo. Total harga adalah nilai bruto; hitung penjualan selesai hanya dari `Completed`.

# %%
display(quality_issues(hasil, "invalid"))
# Out:
#         sumber baris  tingkat         kolom                    masalah  \
# 0       shopee   104    ERROR           qty               NON_POSITIVE
# 1       shopee   304    ERROR        status             INVALID_STATUS
# 2       shopee   590    ERROR    unit_price               NON_POSITIVE
# 3    tokopedia     2    ERROR      quantity               NON_POSITIVE
# 4    tokopedia     2  WARNING         price  PRICE_DIFFERS_FROM_MASTER
# ..         ...   ...      ...           ...                        ...
# 184    website    46    ERROR  total_amount               NON_POSITIVE
# 185    website    67    ERROR        status             INVALID_STATUS
# 186    offline   259    ERROR    item_price               NON_POSITIVE
# 187    offline   264    ERROR         units               NON_POSITIVE
# 188    offline   354    ERROR        status             INVALID_STATUS
#
#       nilai_asli
# 0              0
# 1    in_progress
# 2         -50000
# 3              0
# 4          27900
# ..           ...
# 184            0
# 185  in_progress
# 186       -50000
# 187            0
# 188  in_progress
#
# [189 rows x 6 columns]

# %% [markdown]
# ## 4. Date format
#
# Tanggal Shopee/Tokopedia: DD/MM/YYYY; Website: MMM DD, YYYY; Offline: DD-MMM-YYYY. Hasil CSV selalu YYYY-MM-DD. Tanggal tidak valid ditolak. Product Master tidak memiliki tanggal transaksi.

# %%
display(quality_issues(hasil, "date"))
if "tanggal_order" in data_bersih:
    display(data_bersih[["order_id", "tanggal_order"]].head(5))
else:
    print("Tidak berlaku: master produk tidak memiliki tanggal transaksi.")
# Out:
#        sumber baris tingkat             kolom       masalah  nilai_asli
# 0      shopee   579   ERROR        order_date  INVALID_DATE  not-a-date
# 1   tokopedia   121   ERROR  transaction_date  INVALID_DATE  not-a-date
# 2   tokopedia   143   ERROR  transaction_date  INVALID_DATE  not-a-date
# 3   tokopedia   152   ERROR  transaction_date  INVALID_DATE  not-a-date
# 4   tokopedia   232   ERROR  transaction_date  INVALID_DATE  not-a-date
# 5   tokopedia   284   ERROR  transaction_date  INVALID_DATE  not-a-date
# 6   tokopedia   289   ERROR  transaction_date  INVALID_DATE  not-a-date
# 7   tokopedia   332   ERROR  transaction_date  INVALID_DATE  not-a-date
# 8   tokopedia   346   ERROR  transaction_date  INVALID_DATE  not-a-date
# 9   tokopedia   373   ERROR  transaction_date  INVALID_DATE  not-a-date
# 10    website   371   ERROR        created_at  INVALID_DATE  not-a-date
# 11    offline   312   ERROR           sold_at  INVALID_DATE  not-a-date
#      order_id tanggal_order
# 0  SHP-000519    2026-08-20
# 1  SHP-000266    2026-01-30
# 2  SHP-000160    2026-06-10
# 3  SHP-000580    2026-07-04
# 4  SHP-000453    2026-03-14

# %% [markdown]
# ## 5. Data type
#
# Identifier string, quantity Int64, tanggal datetime, dan uang Decimal. CSV tidak menyimpan tipe data; ekspor tanggal menggunakan YYYY-MM-DD. Teks dirapikan spasinya tanpa merusak nama brand, SKU, shade, atau SPF/PA++++.

# %%
display(type_report(data_bersih))
# Out:
#              kolom           dtype tipe_nilai
# 0         order_id          string        str
# 1       product_id          string        str
# 2     product_name          string        str
# 3         kategori          string        str
# 4         quantity           Int64      int64
# 5      total_harga          object    Decimal
# 6    tanggal_order  datetime64[us]  Timestamp
# 7             kota          string        str
# 8          channel          string        str
# 9           status          string        str
# 10  customer_email          string        str
# 11    harga_satuan          object    Decimal
# 12     customer_id          string        str

# %% [markdown]
# ## 6. Product consistency
#
# Variasi huruf besar/kecil, spasi, underscore, dan hyphen dicocokkan ke master. Nama produk dan kategori mengikuti master. Produk tidak dikenal/typo ambigu ditolak, tanpa menebak SKU. Pada master, SKU harus unik.

# %%
display(data_bersih[["product_id", "product_name", "kategori"]].drop_duplicates())
display(quality_issues(hasil, "product"))
# Out:
#      product_id                                       product_name  \
# 0   KHF-SKC-001  Kahf Triple Protection Sunscreen Moisturizer S...
# 1   WND-BDY-001             Wonderly Body Mist Sweet Blossom 100ml
# 2   WRD-SKC-003             Wardah Aloe Hydramild Moisturizer 40ml
# 3   WRD-MUP-001         Wardah Colorfit Velvet Matte Lip Mousse 03
# 4   KHF-BDY-001        Kahf Face Wash Oil and Comedo Defense 100ml
# 5   MKO-MUP-002    Make Over Powerstay Matte Powder Foundation N20
# 6   TVI-SKC-001            TAVI Urban Shield Sunscreen SPF 50 30ml
# 7   MKO-MUP-001  Make Over Powerstay Weightless Liquid Foundati...
# 8   EMN-SKC-001                 Emina Bright Stuff Face Wash 100ml
# 13  BDF-BDY-001                  Biodef Body Wash Fresh Care 450ml
# 14  WRD-SKC-002             Wardah Lightening Micellar Water 100ml
# 16  LBR-SKC-001  LABORE BiomeProtect Physical Sunscreen SPF 50 ...
# 17  WRD-MUP-002           Wardah Colorfit Perfect Glow Cushion 13N
# 21  INS-MUP-001        Instaperfect Skincover Air Cushion 02 Beige
# 24  EMN-SKC-002                Emina Sun Battle SPF 50 PA++++ 30ml
# 25  WRD-SKC-001  Wardah UV Shield Aqua Fresh Essence SPF 50 PA+...
# 27  LBR-SKC-002                   LABORE Barrier Revive Cream 30ml
# 31  EMN-MUP-002                  Emina Glossy Stain 01 Autumn Bell
# 32  EMN-MUP-001                  Emina Cheek Lit Cream Blush Peach
# 42  CRY-SKC-001    Crystallure Supreme Revitalizing Oil Serum 20ml
#
#          kategori
# 0   Mens Grooming
# 1       Fragrance
# 2        Skincare
# 3          Makeup
# 4   Mens Grooming
# 5          Makeup
# 6        Skincare
# 7          Makeup
# 8        Skincare
# 13      Body Care
# 14       Skincare
# 16       Skincare
# 17         Makeup
# 21         Makeup
# 24       Skincare
# 25       Skincare
# 27       Skincare
# 31         Makeup
# 32         Makeup
# 42       Skincare
#        sumber baris tingkat               kolom           masalah  \
# 0      shopee    94   ERROR        product_name  UNMAPPED_PRODUCT
# 1   tokopedia     5   ERROR           item_name  UNMAPPED_PRODUCT
# 2   tokopedia    10   ERROR           item_name  UNMAPPED_PRODUCT
# 3   tokopedia    17   ERROR           item_name  UNMAPPED_PRODUCT
# 4   tokopedia    25   ERROR           item_name  UNMAPPED_PRODUCT
# 5   tokopedia    31   ERROR           item_name  UNMAPPED_PRODUCT
# 6   tokopedia    32   ERROR           item_name  UNMAPPED_PRODUCT
# 7   tokopedia    35   ERROR           item_name  UNMAPPED_PRODUCT
# 8   tokopedia    53   ERROR           item_name  UNMAPPED_PRODUCT
# 9   tokopedia    67   ERROR           item_name  UNMAPPED_PRODUCT
# 10  tokopedia    79   ERROR           item_name  UNMAPPED_PRODUCT
# 11  tokopedia    84   ERROR           item_name  UNMAPPED_PRODUCT
# 12  tokopedia    89   ERROR           item_name  UNMAPPED_PRODUCT
# 13  tokopedia   100   ERROR           item_name  UNMAPPED_PRODUCT
# 14  tokopedia   132   ERROR           item_name  UNMAPPED_PRODUCT
# 15  tokopedia   140   ERROR           item_name  UNMAPPED_PRODUCT
# 16  tokopedia   144   ERROR           item_name  UNMAPPED_PRODUCT
# 17  tokopedia   151   ERROR           item_name  UNMAPPED_PRODUCT
# 18  tokopedia   167   ERROR           item_name  UNMAPPED_PRODUCT
# 19  tokopedia   168   ERROR           item_name  UNMAPPED_PRODUCT
# 20  tokopedia   172   ERROR           item_name  UNMAPPED_PRODUCT
# 21  tokopedia   188   ERROR           item_name  UNMAPPED_PRODUCT
# 22  tokopedia   239   ERROR           item_name  UNMAPPED_PRODUCT
# 23  tokopedia   246   ERROR           item_name  UNMAPPED_PRODUCT
# 24  tokopedia   249   ERROR           item_name  UNMAPPED_PRODUCT
# 25  tokopedia   273   ERROR           item_name  UNMAPPED_PRODUCT
# 26  tokopedia   276   ERROR           item_name  UNMAPPED_PRODUCT
# 27  tokopedia   277   ERROR           item_name  UNMAPPED_PRODUCT
# 28  tokopedia   278   ERROR           item_name  UNMAPPED_PRODUCT
# 29  tokopedia   299   ERROR           item_name  UNMAPPED_PRODUCT
# 30  tokopedia   307   ERROR           item_name  UNMAPPED_PRODUCT
# 31  tokopedia   309   ERROR           item_name  UNMAPPED_PRODUCT
# 32  tokopedia   317   ERROR           item_name  UNMAPPED_PRODUCT
# 33  tokopedia   322   ERROR           item_name  UNMAPPED_PRODUCT
# 34  tokopedia   324   ERROR           item_name  UNMAPPED_PRODUCT
# 35  tokopedia   326   ERROR           item_name  UNMAPPED_PRODUCT
# 36  tokopedia   335   ERROR           item_name  UNMAPPED_PRODUCT
# 37  tokopedia   343   ERROR           item_name  UNMAPPED_PRODUCT
# 38  tokopedia   354   ERROR           item_name  UNMAPPED_PRODUCT
# 39  tokopedia   364   ERROR           item_name  UNMAPPED_PRODUCT
# 40  tokopedia   365   ERROR           item_name  UNMAPPED_PRODUCT
# 41  tokopedia   385   ERROR           item_name  UNMAPPED_PRODUCT
# 42  tokopedia   388   ERROR           item_name  UNMAPPED_PRODUCT
# 43  tokopedia   390   ERROR           item_name  UNMAPPED_PRODUCT
# 44  tokopedia   396   ERROR           item_name  UNMAPPED_PRODUCT
# 45  tokopedia   397   ERROR           item_name  UNMAPPED_PRODUCT
# 46    website   106   ERROR  product_identifier  UNMAPPED_PRODUCT
# 47    offline   103   ERROR    item_description  UNMAPPED_PRODUCT
#
#                               nilai_asli
# 0              Wadah UV Sheild Sunscreen
# 1     Putri Hair Treatment Shampoo 250ml
# 2     Putri Hair Treatment Shampoo 250ml
# 3                Nourish Hand Cream 50ml
# 4                 Brigthning Serumm 30ml
# 5                Nourish Hand Cream 50ml
# 6     Putri Hair Treatment Shampoo 250ml
# 7                Nourish Hand Cream 50ml
# 8            Glowly Vitamin C Serum 20ml
# 9     Putri Hair Treatment Shampoo 250ml
# 10           Glowly Vitamin C Serum 20ml
# 11    Putri-Hair-Treatment-Shampoo-250ml
# 12    Putri Hair Treatment Shampoo 250ml
# 13    Putri Hair Treatment Shampoo 250ml
# 14                Brigthning Serumm 30ml
# 15               Nourish Hand Cream 50ml
# 16           Glowly Vitamin C Serum 20ml
# 17    Putri Hair Treatment Shampoo 250ml
# 18                Brigthning Serumm 30ml
# 19   Putri Hair Treatment Shampoo 250ml
# 20           Glowly Vitamin C Serum 20ml
# 21               Nourish Hand Cream 50ml
# 22                Brigthning Serumm 30ml
# 23    Putri Hair Treatment Shampoo 250ml
# 24           Glowly Vitamin C Serum 20ml
# 25           Glowly Vitamin C Serum 20ml
# 26               Nourish Hand Cream 50ml
# 27               Nourish Hand Cream 50ml
# 28               Nourish Hand Cream 50ml
# 29           Glowly Vitamin C Serum 20ml
# 30               Nourish Hand Cream 50ml
# 31               Nourish Hand Cream 50ml
# 32           Glowly Vitamin C Serum 20ml
# 33                Brigthning Serumm 30ml
# 34                Brigthning Serumm 30ml
# 35           Glowly Vitamin C Serum 20ml
# 36    Putri Hair Treatment Shampoo 250ml
# 37                Brigthning Serumm 30ml
# 38    Putri Hair Treatment Shampoo 250ml
# 39                Brigthning Serumm 30ml
# 40           Glowly Vitamin C Serum 20ml
# 41                Brigthning Serumm 30ml
# 42                Brigthning Serumm 30ml
# 43                Brigthning Serumm 30ml
# 44                Brigthning Serumm 30ml
# 45                Brigthning Serumm 30ml
# 46             Wadah UV Sheild Sunscreen
# 47             Wadah UV Sheild Sunscreen

# %% [markdown]
# ## Hasil akhir
#
# Format dan urutan kolom sama untuk semua transaksi. `kota` adalah kota pelanggan online atau kota toko offline; Website yang tidak memiliki kota tetap kosong. Nama channel tetap Shopee/Tokopedia/Website/Offline Store agar bisa dibandingkan.
#
# Hasil utama: `data/processed/clean/`. Notebook ini menyimpan file bersih sumber yang dibahas; `analisa.ipynb` menyimpan seluruh sumber, `sales.csv`, `summary.csv`, serta satu `quality_issues.csv` untuk detail masalah.

# %%
ringkasan = summary(hasil)
assert (ringkasan["awal"] == ringkasan["bersih"] + ringkasan["duplikat"] + ringkasan["ditolak"]).all()
display(ringkasan)
display(data_bersih.head(10))
folder_hasil = export_analysis(hasil)
print("Tersimpan:", folder_hasil)
# Out:
#       sumber  awal  bersih  duplikat  ditolak
# 0    product    20      20         0        0
# 1     shopee   618     595        18        5
# 2  tokopedia   400     334         1       65
# 3    website   412     395        12        5
# 4    offline   360     345        10        5
#      order_id   product_id                                       product_name  \
# 0  SHP-000519  KHF-SKC-001  Kahf Triple Protection Sunscreen Moisturizer S...
# 1  SHP-000266  WND-BDY-001             Wonderly Body Mist Sweet Blossom 100ml
# 2  SHP-000160  WRD-SKC-003             Wardah Aloe Hydramild Moisturizer 40ml
# 3  SHP-000580  WRD-MUP-001         Wardah Colorfit Velvet Matte Lip Mousse 03
# 4  SHP-000453  KHF-BDY-001        Kahf Face Wash Oil and Comedo Defense 100ml
# 5  SHP-000448  MKO-MUP-002    Make Over Powerstay Matte Powder Foundation N20
# 6  SHP-000418  TVI-SKC-001            TAVI Urban Shield Sunscreen SPF 50 30ml
# 7  SHP-000122  MKO-MUP-001  Make Over Powerstay Weightless Liquid Foundati...
# 8  SHP-000270  EMN-SKC-001                 Emina Bright Stuff Face Wash 100ml
# 9  SHP-000176  MKO-MUP-001  Make Over Powerstay Weightless Liquid Foundati...
#
#         kategori  quantity total_harga tanggal_order        kota channel  \
# 0  Mens Grooming         1    54900.00    2026-08-20     Bandung  Shopee
# 1      Fragrance         2    91800.00    2026-01-30  Yogyakarta  Shopee
# 2       Skincare         3   137700.00    2026-06-10    Semarang  Shopee
# 3         Makeup         1    62900.00    2026-07-04    Semarang  Shopee
# 4  Mens Grooming         4   171600.00    2026-03-14    Semarang  Shopee
# 5         Makeup         1   179000.00    2026-07-30     Jakarta  Shopee
# 6       Skincare         5   449500.00    2026-03-18     Jakarta  Shopee
# 7         Makeup         1   169000.00    2026-08-02    Surabaya  Shopee
# 8       Skincare         1    27900.00    2026-03-05    Surabaya  Shopee
# 9         Makeup         5   845000.00    2026-04-19     Jakarta  Shopee
#
#       status customer_email harga_satuan customer_id
# 0  Completed           <NA>     54900.00        C002
# 1  Cancelled           <NA>     45900.00        C004
# 2   Returned           <NA>     45900.00        C005
# 3  Completed           <NA>     62900.00        C005
# 4  Completed           <NA>     42900.00        C005
# 5   Returned           <NA>    179000.00        C001
# 6  Completed           <NA>     89900.00        C001
# 7   Returned           <NA>    169000.00        C003
# 8  Completed           <NA>     27900.00        C003
# 9  Completed           <NA>    169000.00        C001
# Tersimpan: C:\Users\ADVAN\OneDrive - Universitas Teknologi Yogyakarta\Rinaldi\Ecommerce Sales\data\processed\clean
