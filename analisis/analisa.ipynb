# %% [markdown]
# # Data Quality — Semua Sumber
#
# Jalankan **Run All** dengan kernel `env`. Keenam pemeriksaan di bawah memakai aturan yang sama untuk semua sumber. Hasil transaksi mengikuti kontrak canonical 12 kolom; `product_id` memakai SKU asli dari Product Master.
#
# Product Master tetap berisi identitas produk dan harga referensi. Data sumber tetap utuh. Semua aturan dijalankan saat persiapan agar pemeriksaan duplikat sudah memperhitungkan hasil mapping produk; enam bagian berikut memperlihatkan hasil tiap pemeriksaan.

# %%
from pathlib import Path
import sys
from IPython.display import display

ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents]
            if (p / "pipeline/validation/analysis.py").exists())
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from pipeline.validation.analysis import (
    load_analysis, standard_data, missing_values, quality_issues,
    type_report, summary, export_analysis,
)

SOURCE = "all"
hasil = load_analysis(SOURCE, ROOT / "data/source")
data_bersih = standard_data(hasil)

# %% [markdown]
# ## 1. Missing value
#
# Field wajib: order ID, tanggal, produk, quantity, harga satuan, status; total transaksi Website juga wajib. Semua field master wajib. Baris yang tidak memenuhi syarat ditolak. Customer/kota/email yang tidak tersedia tetap kosong, tanpa dummy. Field opsional kosong yang tersedia dalam source dicatat sebagai warning.

# %%
display(missing_values(hasil))
display(quality_issues(hasil, "missing"))
# Out:
#        sumber               kolom  jumlah_kosong
# 0     product                 sku              0
# 1     product        product_name              0
# 2     product               brand              0
# 3     product            category              0
# 4     product               price              0
# 5      shopee            order_id              0
# 6      shopee          order_date              0
# 7      shopee        product_name              0
# 8      shopee                 qty              0
# 9      shopee          unit_price              0
# 10     shopee       customer_name              1
# 11     shopee       customer_city              1
# 12     shopee      payment_method              1
# 13     shopee              status              0
# 14  tokopedia      transaction_id              0
# 15  tokopedia    transaction_date              0
# 16  tokopedia           item_name              0
# 17  tokopedia            quantity              0
# 18  tokopedia               price              0
# 19  tokopedia          buyer_name              1
# 20  tokopedia                city              1
# 21  tokopedia             payment              1
# 22  tokopedia              status              0
# 23    website          invoice_no              0
# 24    website          created_at              0
# 25    website  product_identifier              0
# 26    website            quantity              0
# 27    website          unit_price              0
# 28    website        total_amount              0
# 29    website      customer_email              0
# 30    website              status              0
# 31    offline      pos_receipt_no              0
# 32    offline             sold_at              0
# 33    offline    item_description              0
# 34    offline               units              0
# 35    offline          item_price              0
# 36    offline          store_name              0
# 37    offline          store_city              1
# 38    offline        payment_type              1
# 39    offline              status              0
#       sumber baris  tingkat           kolom           masalah nilai_asli
# 0     shopee    12  WARNING   customer_name  MISSING_OPTIONAL
# 1     shopee    16  WARNING   customer_city  MISSING_OPTIONAL
# 2     shopee    20  WARNING  payment_method  MISSING_OPTIONAL
# 3  tokopedia    12  WARNING      buyer_name  MISSING_OPTIONAL
# 4  tokopedia    16  WARNING            city  MISSING_OPTIONAL
# 5  tokopedia    20  WARNING         payment  MISSING_OPTIONAL
# 6    offline    16  WARNING      store_city  MISSING_OPTIONAL
# 7    offline    20  WARNING    payment_type  MISSING_OPTIONAL

# %% [markdown]
# ## 2. Duplicate
#
# Business key: `(channel, order_id)` untuk dataset satu item per order saat ini; master memakai `product_id`/SKU. Record yang sama disimpan satu kali. Jika key sama tetapi nilainya berbeda, semua versi ditolak untuk ditinjau. Bila kelak order memiliki beberapa item, tambahkan line ID dari sumber.

# %%
display(quality_issues(hasil, "duplicate"))
# Out:
#       sumber baris tingkat         kolom                 masalah nilai_asli
# 0     shopee    51    INFO  business_key  DUPLICATE_BUSINESS_KEY   SHP-0006
# 1  tokopedia    51    INFO  business_key  DUPLICATE_BUSINESS_KEY   TKP-0106
# 2    offline    51    INFO  business_key  DUPLICATE_BUSINESS_KEY   POS-0306

# %% [markdown]
# ## 3. Invalid value
#
# Quantity wajib integer positif. Harga wajib positif dan maksimal dua desimal. Total harus sama dengan quantity × harga satuan. Status dataset saat ini: `Completed`, `Cancelled`, `Returned`; status lain ditolak. Harga berbeda dari master diberi warning karena mungkin promo. Total harga adalah nilai bruto; hitung penjualan selesai hanya dari `Completed`.

# %%
display(quality_issues(hasil, "invalid"))
# Out:
#        sumber baris tingkat         kolom         masalah   nilai_asli
# 0      shopee     4   ERROR           qty    NON_POSITIVE            0
# 1      shopee     8   ERROR    unit_price    NON_POSITIVE       -50000
# 2      shopee    24   ERROR        status  INVALID_STATUS  in_progress
# 3   tokopedia     4   ERROR      quantity    NON_POSITIVE            0
# 4   tokopedia     8   ERROR         price    NON_POSITIVE       -50000
# 5   tokopedia    24   ERROR        status  INVALID_STATUS  in_progress
# 6     website     4   ERROR      quantity    NON_POSITIVE            0
# 7     website     4   ERROR  total_amount    NON_POSITIVE            0
# 8     website     8   ERROR    unit_price    NON_POSITIVE       -50000
# 9     website     8   ERROR  total_amount    NON_POSITIVE      -100000
# 10    website    24   ERROR        status  INVALID_STATUS  in_progress
# 11    offline     4   ERROR         units    NON_POSITIVE            0
# 12    offline     8   ERROR    item_price    NON_POSITIVE       -50000
# 13    offline    24   ERROR        status  INVALID_STATUS  in_progress

# %% [markdown]
# ## 4. Date format
#
# Tanggal Shopee/Tokopedia: DD/MM/YYYY; Website: MMM DD, YYYY; Offline: DD-MMM-YYYY. Hasil CSV selalu YYYY-MM-DD. Tanggal tidak valid ditolak. Product Master tidak memiliki tanggal transaksi.

# %%
display(quality_issues(hasil, "date"))
if "tanggal_order" in data_bersih:
    display(data_bersih[["order_id", "tanggal_order"]].head(5))
else:
    print("Tidak berlaku: master produk tidak memiliki tanggal transaksi.")
# Out:
#        sumber baris tingkat             kolom       masalah  \
# 0      shopee    32   ERROR        order_date  INVALID_DATE
# 1   tokopedia    32   ERROR  transaction_date  INVALID_DATE
# 2     website     1   ERROR        created_at  INVALID_DATE
# 3     website     2   ERROR        created_at  INVALID_DATE
# 4     website     3   ERROR        created_at  INVALID_DATE
# 5     website     4   ERROR        created_at  INVALID_DATE
# 6     website     5   ERROR        created_at  INVALID_DATE
# 7     website     6   ERROR        created_at  INVALID_DATE
# 8     website     7   ERROR        created_at  INVALID_DATE
# 9     website     8   ERROR        created_at  INVALID_DATE
# 10    website     9   ERROR        created_at  INVALID_DATE
# 11    website    10   ERROR        created_at  INVALID_DATE
# 12    website    11   ERROR        created_at  INVALID_DATE
# 13    website    12   ERROR        created_at  INVALID_DATE
# 14    website    13   ERROR        created_at  INVALID_DATE
# 15    website    14   ERROR        created_at  INVALID_DATE
# 16    website    15   ERROR        created_at  INVALID_DATE
# 17    website    16   ERROR        created_at  INVALID_DATE
# 18    website    17   ERROR        created_at  INVALID_DATE
# 19    website    18   ERROR        created_at  INVALID_DATE
# 20    website    19   ERROR        created_at  INVALID_DATE
# 21    website    20   ERROR        created_at  INVALID_DATE
# 22    website    21   ERROR        created_at  INVALID_DATE
# 23    website    22   ERROR        created_at  INVALID_DATE
# 24    website    23   ERROR        created_at  INVALID_DATE
# 25    website    24   ERROR        created_at  INVALID_DATE
# 26    website    25   ERROR        created_at  INVALID_DATE
# 27    website    26   ERROR        created_at  INVALID_DATE
# 28    website    27   ERROR        created_at  INVALID_DATE
# 29    website    28   ERROR        created_at  INVALID_DATE
# 30    website    29   ERROR        created_at  INVALID_DATE
# 31    website    30   ERROR        created_at  INVALID_DATE
# 32    website    31   ERROR        created_at  INVALID_DATE
# 33    website    32   ERROR        created_at  INVALID_DATE
# 34    website    33   ERROR        created_at  INVALID_DATE
# 35    website    34   ERROR        created_at  INVALID_DATE
# 36    website    35   ERROR        created_at  INVALID_DATE
# 37    website    36   ERROR        created_at  INVALID_DATE
# 38    website    37   ERROR        created_at  INVALID_DATE
# 39    website    38   ERROR        created_at  INVALID_DATE
# 40    website    39   ERROR        created_at  INVALID_DATE
# 41    website    40   ERROR        created_at  INVALID_DATE
# 42    website    41   ERROR        created_at  INVALID_DATE
# 43    website    42   ERROR        created_at  INVALID_DATE
# 44    website    43   ERROR        created_at  INVALID_DATE
# 45    website    44   ERROR        created_at  INVALID_DATE
# 46    website    45   ERROR        created_at  INVALID_DATE
# 47    website    46   ERROR        created_at  INVALID_DATE
# 48    website    47   ERROR        created_at  INVALID_DATE
# 49    website    48   ERROR        created_at  INVALID_DATE
# 50    website    49   ERROR        created_at  INVALID_DATE
# 51    website    50   ERROR        created_at  INVALID_DATE
# 52    website    51   ERROR        created_at  INVALID_DATE
# 53    offline    32   ERROR           sold_at  INVALID_DATE
#
#              nilai_asli
# 0            not-a-date
# 1            not-a-date
# 2   2026-01-09T10:30:00
# 3   2026-05-17T10:30:00
# 4   2026-06-03T10:30:00
# 5   2026-06-22T10:30:00
# 6   2026-01-04T10:30:00
# 7   2026-05-17T10:30:00
# 8   2026-08-21T10:30:00
# 9   2026-06-05T10:30:00
# 10  2026-02-19T10:30:00
# 11  2026-07-29T10:30:00
# 12  2026-02-01T10:30:00
# 13  2026-01-12T10:30:00
# 14  2026-01-07T10:30:00
# 15  2026-04-23T10:30:00
# 16  2026-08-13T10:30:00
# 17  2026-08-20T10:30:00
# 18  2026-01-22T10:30:00
# 19  2026-03-24T10:30:00
# 20  2026-02-06T10:30:00
# 21  2026-06-11T10:30:00
# 22  2026-03-13T10:30:00
# 23  2026-03-16T10:30:00
# 24  2026-03-06T10:30:00
# 25  2026-01-23T10:30:00
# 26  2026-01-11T10:30:00
# 27  2026-04-14T10:30:00
# 28  2026-04-23T10:30:00
# 29  2026-03-12T10:30:00
# 30  2026-07-04T10:30:00
# 31  2026-06-03T10:30:00
# 32  2026-04-05T10:30:00
# 33           not-a-date
# 34  2026-04-22T10:30:00
# 35  2026-08-05T10:30:00
# 36  2026-08-06T10:30:00
# 37  2026-06-03T10:30:00
# 38  2026-07-22T10:30:00
# 39  2026-08-07T10:30:00
# 40  2026-07-05T10:30:00
# 41  2026-01-28T10:30:00
# 42  2026-01-30T10:30:00
# 43  2026-03-07T10:30:00
# 44  2026-03-25T10:30:00
# 45  2026-02-15T10:30:00
# 46  2026-04-12T10:30:00
# 47  2026-03-03T10:30:00
# 48  2026-02-28T10:30:00
# 49  2026-02-24T10:30:00
# 50  2026-05-20T10:30:00
# 51  2026-08-02T10:30:00
# 52  2026-05-17T10:30:00
# 53           not-a-date
#    order_id tanggal_order
# 0  SHP-0001    2026-08-20
# 1  SHP-0002    2026-01-14
# 2  SHP-0003    2026-06-27
# 3  SHP-0005    2026-02-24
# 4  SHP-0006    2026-05-04

# %% [markdown]
# ## 5. Data type
#
# Identifier string, quantity Int64, tanggal datetime, dan uang Decimal. CSV tidak menyimpan tipe data; ekspor tanggal menggunakan YYYY-MM-DD. Teks dirapikan spasinya tanpa merusak nama brand, SKU, shade, atau SPF/PA++++.

# %%
display(type_report(data_bersih))
# Out:
#              kolom           dtype tipe_nilai
# 0         order_id          string        str
# 1       product_id          string        str
# 2     product_name          string        str
# 3         kategori          string        str
# 4         quantity           Int64      int64
# 5      total_harga          object    Decimal
# 6    tanggal_order  datetime64[us]  Timestamp
# 7             kota          string        str
# 8          channel          string        str
# 9           status          string        str
# 10  customer_email          string     kosong
# 11    harga_satuan          object    Decimal

# %% [markdown]
# ## 6. Product consistency
#
# Variasi huruf besar/kecil, spasi, underscore, dan hyphen dicocokkan ke master. Nama produk dan kategori mengikuti master. Produk tidak dikenal/typo ambigu ditolak, tanpa menebak SKU. Pada master, SKU harus unik.

# %%
display(data_bersih[["product_id", "product_name", "kategori"]].drop_duplicates())
display(quality_issues(hasil, "product"))
# Out:
#      product_id                                       product_name  \
# 0   WRD-MUP-002           Wardah Colorfit Perfect Glow Cushion 13N
# 1   LBR-SKC-002                   LABORE Barrier Revive Cream 30ml
# 2   EMN-SKC-001                 Emina Bright Stuff Face Wash 100ml
# 3   KHF-BDY-001        Kahf Face Wash Oil and Comedo Defense 100ml
# 5   EMN-SKC-002                Emina Sun Battle SPF 50 PA++++ 30ml
# 6   WND-BDY-001             Wonderly Body Mist Sweet Blossom 100ml
# 7   MKO-MUP-002    Make Over Powerstay Matte Powder Foundation N20
# 8   BDF-BDY-001                  Biodef Body Wash Fresh Care 450ml
# 9   WRD-MUP-001         Wardah Colorfit Velvet Matte Lip Mousse 03
# 10  CRY-SKC-001    Crystallure Supreme Revitalizing Oil Serum 20ml
# 13  WRD-SKC-002             Wardah Lightening Micellar Water 100ml
# 14  TVI-SKC-001            TAVI Urban Shield Sunscreen SPF 50 30ml
# 15  EMN-MUP-001                  Emina Cheek Lit Cream Blush Peach
# 20  EMN-MUP-002                  Emina Glossy Stain 01 Autumn Bell
# 25  WRD-SKC-003             Wardah Aloe Hydramild Moisturizer 40ml
# 26  MKO-MUP-001  Make Over Powerstay Weightless Liquid Foundati...
# 31  INS-MUP-001        Instaperfect Skincover Air Cushion 02 Beige
# 34  WRD-SKC-001  Wardah UV Shield Aqua Fresh Essence SPF 50 PA+...
# 35  KHF-SKC-001  Kahf Triple Protection Sunscreen Moisturizer S...
# 59  LBR-SKC-001  LABORE BiomeProtect Physical Sunscreen SPF 50 ...
#
#          kategori
# 0          Makeup
# 1        Skincare
# 2        Skincare
# 3   Mens Grooming
# 5        Skincare
# 6       Fragrance
# 7          Makeup
# 8       Body Care
# 9          Makeup
# 10       Skincare
# 13       Skincare
# 14       Skincare
# 15         Makeup
# 20         Makeup
# 25       Skincare
# 26         Makeup
# 31         Makeup
# 34       Skincare
# 35  Mens Grooming
# 59       Skincare
#       sumber baris tingkat             kolom           masalah  \
# 0     shopee    28   ERROR      product_name  UNMAPPED_PRODUCT
# 1  tokopedia    28   ERROR         item_name  UNMAPPED_PRODUCT
# 2    offline    28   ERROR  item_description  UNMAPPED_PRODUCT
#
#                nilai_asli
# 0  Brigthning Serumm 30ml
# 1  Brigthning Serumm 30ml
# 2  Brigthning Serumm 30ml

# %% [markdown]
# ## Hasil akhir
#
# Format dan urutan kolom sama untuk semua transaksi. `kota` adalah kota pelanggan online atau kota toko offline; Website yang tidak memiliki kota tetap kosong. Nama channel tetap Shopee/Tokopedia/Website/Offline Store agar bisa dibandingkan.
#
# Hasil utama: `data/processed/clean/`. Notebook ini menyimpan file bersih sumber yang dibahas; `analisa.ipynb` menyimpan seluruh sumber, `sales.csv`, `summary.csv`, serta satu `quality_issues.csv` untuk detail masalah.

# %%
ringkasan = summary(hasil)
assert (ringkasan["awal"] == ringkasan["bersih"] + ringkasan["duplikat"] + ringkasan["ditolak"]).all()
display(ringkasan)
display(data_bersih.head(10))
folder_hasil = export_analysis(hasil)
print("Tersimpan:", folder_hasil)
# Out:
#       sumber  awal  bersih  duplikat  ditolak
# 0    product    20      20         0        0
# 1     shopee    51      45         1        5
# 2  tokopedia    51      45         1        5
# 3    website    51       0         0       51
# 4    offline    51      45         1        5
#    order_id   product_id                                     product_name  \
# 0  SHP-0001  WRD-MUP-002         Wardah Colorfit Perfect Glow Cushion 13N
# 1  SHP-0002  LBR-SKC-002                 LABORE Barrier Revive Cream 30ml
# 2  SHP-0003  EMN-SKC-001               Emina Bright Stuff Face Wash 100ml
# 3  SHP-0005  KHF-BDY-001      Kahf Face Wash Oil and Comedo Defense 100ml
# 4  SHP-0006  KHF-BDY-001      Kahf Face Wash Oil and Comedo Defense 100ml
# 5  SHP-0007  EMN-SKC-002              Emina Sun Battle SPF 50 PA++++ 30ml
# 6  SHP-0009  WND-BDY-001           Wonderly Body Mist Sweet Blossom 100ml
# 7  SHP-0010  MKO-MUP-002  Make Over Powerstay Matte Powder Foundation N20
# 8  SHP-0011  BDF-BDY-001                Biodef Body Wash Fresh Care 450ml
# 9  SHP-0012  WRD-MUP-001       Wardah Colorfit Velvet Matte Lip Mousse 03
#
#         kategori  quantity total_harga tanggal_order        kota channel  \
# 0         Makeup         1   109000.00    2026-08-20    Semarang  Shopee
# 1       Skincare         3   357000.00    2026-01-14    Surabaya  Shopee
# 2       Skincare         3    83700.00    2026-06-27     Bandung  Shopee
# 3  Mens Grooming         1    42900.00    2026-02-24    Semarang  Shopee
# 4  Mens Grooming         2    85800.00    2026-05-04  Yogyakarta  Shopee
# 5       Skincare         3   149700.00    2026-08-12    Surabaya  Shopee
# 6      Fragrance         1    45900.00    2026-03-18     Bandung  Shopee
# 7         Makeup         1   179000.00    2026-06-01    Surabaya  Shopee
# 8      Body Care         1    35900.00    2026-04-16     Jakarta  Shopee
# 9         Makeup         3   188700.00    2026-08-05  Yogyakarta  Shopee
#
#       status customer_email harga_satuan
# 0  Cancelled           <NA>    109000.00
# 1   Returned           <NA>    119000.00
# 2  Completed           <NA>     27900.00
# 3  Completed           <NA>     42900.00
# 4   Returned           <NA>     42900.00
# 5  Completed           <NA>     49900.00
# 6  Completed           <NA>     45900.00
# 7  Completed           <NA>    179000.00
# 8  Completed           <NA>     35900.00
# 9  Completed           <NA>     62900.00
# Tersimpan: C:\Users\ADVAN\OneDrive - Universitas Teknologi Yogyakarta\Rinaldi\Ecommerce Sales\data\processed\clean
